# %% [markdown]
# # Tutorial 11 - add_efficiency_coulomb

# %% [markdown]
# ## Step 0: Setup the project and prepare the data

# %%
from pathlib import Path

import pydpeet as eet

# %% [markdown]
# We will use "ERROR" as the logging style for better readability of the notebook

# %%
eet.set_logging_style("INFO")

# %%
standardized_data = eet.read(
    input_path=str(Path.cwd().parent.parent / "res" / "raw_data_from_cyclers" / "Cal_Ageing_Checkup1.xlsx"),
    config=eet.ReadConfig.Neware_8_0_0_516,
)
# Out:
# INFO | D:\Coding\PyDPEET_BA\pythonProject\pydpeet\src\pydpeet\io\convert.py:321 | converting file to pandas DataFrame...
# INFO | D:\Coding\PyDPEET_BA\pythonProject\pydpeet\src\pydpeet\io\device\neware_8_0_0_516\reader.py:61 | Reading sheets from D:\Coding\PyDPEET_BA\pythonProject\pydpeet\docs\res\raw_data_from_cyclers\Cal_Ageing_Checkup1.xlsx...
# INFO | D:\Coding\PyDPEET_BA\pythonProject\pydpeet\src\pydpeet\io\device\neware_8_0_0_516\reader.py:302 | hadling record auxvol auxtemp sheets...
# INFO | D:\Coding\PyDPEET_BA\pythonProject\pydpeet\src\pydpeet\io\device\neware_8_0_0_516\reader.py:218 | Handling sheets cycle, step and test...
# INFO | D:\Coding\PyDPEET_BA\pythonProject\pydpeet\src\pydpeet\io\device\neware_8_0_0_516\reader.py:219 | merging cycle and step...
# INFO | D:\Coding\PyDPEET_BA\pythonProject\pydpeet\src\pydpeet\io\device\neware_8_0_0_516\reader.py:345 | checking if headers need to be reindexed...
# INFO | D:\Coding\PyDPEET_BA\pythonProject\pydpeet\src\pydpeet\io\device\neware_8_0_0_516\reader.py:347 | reindexing headers...
# INFO | D:\Coding\PyDPEET_BA\pythonProject\pydpeet\src\pydpeet\io\device\neware_8_0_0_516\reader.py:311 | merging record and auxvol...
# INFO | D:\Coding\PyDPEET_BA\pythonProject\pydpeet\src\pydpeet\io\device\neware_8_0_0_516\reader.py:244 | handling test sheet...
# INFO | D:\Coding\PyDPEET_BA\pythonProject\pydpeet\src\pydpeet\io\device\neware_8_0_0_516\reader.py:224 | merging cycle_step_test and test...
# INFO | D:\Coding\PyDPEET_BA\pythonProject\pydpeet\src\pydpeet\io\device\neware_8_0_0_516\reader.py:345 | checking if headers need to be reindexed...
# INFO | D:\Coding\PyDPEET_BA\pythonProject\pydpeet\src\pydpeet\io\device\neware_8_0_0_516\reader.py:347 | reindexing headers...
# INFO | D:\Coding\PyDPEET_BA\pythonProject\pydpeet\src\pydpeet\io\device\neware_8_0_0_516\reader.py:318 | merging record_auxvol and auxtemp...
# INFO | D:\Coding\PyDPEET_BA\pythonProject\pydpeet\src\pydpeet\io\device\neware_8_0_0_516\reader.py:376 | handling final merge...
# INFO | D:\Coding\PyDPEET_BA\pythonProject\pydpeet\src\pydpeet\io\convert.py:365 | mapping columns...
# WARNING | D:\Coding\PyDPEET_BA\pythonProject\pydpeet\src\pydpeet\utils\guardrails.py:16 | Column 'Voltage(V)' contains NaN values.
# WARNING | D:\Coding\PyDPEET_BA\pythonProject\pydpeet\src\pydpeet\utils\guardrails.py:16 | Column 'Current[A] - record' contains NaN values.
# WARNING | D:\Coding\PyDPEET_BA\pythonProject\pydpeet\src\pydpeet\utils\guardrails.py:16 | Column 'T1' contains NaN values.
# WARNING | D:\Coding\PyDPEET_BA\pythonProject\pydpeet\src\pydpeet\utils\guardrails.py:16 | Column 'Total Time' contains NaN values.
# WARNING | D:\Coding\PyDPEET_BA\pythonProject\pydpeet\src\pydpeet\utils\guardrails.py:16 | Column 'Date' contains NaN values.
# WARNING | D:\Coding\PyDPEET_BA\pythonProject\pydpeet\src\pydpeet\io\map.py:63 | Missing column: 'EIS_f[Hz]'. Adding Collumn (with None values) named: 'EIS_f[Hz]'.
# WARNING | D:\Coding\PyDPEET_BA\pythonProject\pydpeet\src\pydpeet\io\map.py:63 | Missing column: 'EIS_Z_Real[Ohm]'. Adding Collumn (with None values) named: 'EIS_Z_Real[Ohm]'.
# WARNING | D:\Coding\PyDPEET_BA\pythonProject\pydpeet\src\pydpeet\io\map.py:63 | Missing column: 'EIS_Z_Imag[Ohm]'. Adding Collumn (with None values) named: 'EIS_Z_Imag[Ohm]'.
# WARNING | D:\Coding\PyDPEET_BA\pythonProject\pydpeet\src\pydpeet\io\map.py:63 | Missing column: 'EIS_DC[A]'. Adding Collumn (with None values) named: 'EIS_DC[A]'.
# INFO | D:\Coding\PyDPEET_BA\pythonProject\pydpeet\src\pydpeet\io\convert.py:403 | dropping additional data...
# INFO | D:\Coding\PyDPEET_BA\pythonProject\pydpeet\src\pydpeet\io\convert.py:433 | adding metadata to Dataframe...
# INFO | D:\Coding\PyDPEET_BA\pythonProject\pydpeet\src\pydpeet\io\convert.py:468 | Getting columns in correct order...
# INFO | D:\Coding\PyDPEET_BA\pythonProject\pydpeet\src\pydpeet\io\convert.py:476 | Checking for duplicate extra columns...
# INFO | D:\Coding\PyDPEET_BA\pythonProject\pydpeet\src\pydpeet\io\convert.py:481 | Selecting and ordering standard columns...
# INFO | D:\Coding\PyDPEET_BA\pythonProject\pydpeet\src\pydpeet\io\convert.py:484 | Selecting extra columns...
# INFO | D:\Coding\PyDPEET_BA\pythonProject\pydpeet\src\pydpeet\io\convert.py:487 | Combining standard and extra columns...
# INFO | D:\Coding\PyDPEET_BA\pythonProject\pydpeet\src\pydpeet\io\convert.py:491 | Reordered DataFrame columns!
# INFO | D:\Coding\PyDPEET_BA\pythonProject\pydpeet\src\pydpeet\io\convert.py:569 | Starting to fix data format...
# INFO | D:\Coding\PyDPEET_BA\pythonProject\pydpeet\src\pydpeet\io\convert.py:591 | Using formatter for ReadConfig: ReadConfig.Neware_8_0_0_516
# INFO | D:\Coding\PyDPEET_BA\pythonProject\pydpeet\src\pydpeet\io\convert.py:597 | Data format fixed.
# INFO | D:\Coding\PyDPEET_BA\pythonProject\pydpeet\src\pydpeet\io\utils\timing.py:32 | _convert_file executed in 6.312103 seconds

# %%
df_primitives = eet.add_primitive_segments(standardized_data, config=eet.PrimitiveConfig.DEFAULT)
# Out:
# WARNING | D:\Coding\PyDPEET_BA\pythonProject\pydpeet\src\pydpeet\utils\guardrails.py:16 | Column 'Voltage[V]' contains NaN values.
# WARNING | D:\Coding\PyDPEET_BA\pythonProject\pydpeet\src\pydpeet\utils\guardrails.py:16 | Column 'Current[A]' contains NaN values.
# WARNING | D:\Coding\PyDPEET_BA\pythonProject\pydpeet\src\pydpeet\utils\guardrails.py:16 | Column 'Test_Time[s]' contains NaN values.
# WARNING | D:\Coding\PyDPEET_BA\pythonProject\pydpeet\src\pydpeet\process\sequence\step_analyzer.py:107 | Dropping NaN values in 'Test_Time[s]', dropping duplicates and sorting 'Test_Time[s]' column.
# INFO | D:\Coding\PyDPEET_BA\pythonProject\pydpeet\src\pydpeet\process\sequence\step_analyzer.py:169 | detecting segments in dataframe of size 167370...
# INFO | D:\Coding\PyDPEET_BA\pythonProject\pydpeet\src\pydpeet\process\sequence\utils\console_prints\log_time.py:30 |     0.0010s calculating Power[W]
# INFO | D:\Coding\PyDPEET_BA\pythonProject\pydpeet\src\pydpeet\process\sequence\utils\console_prints\log_time.py:30 |     0.1995s separating Voltage[V] into segments using incremental linear fit
# INFO | D:\Coding\PyDPEET_BA\pythonProject\pydpeet\src\pydpeet\process\sequence\utils\console_prints\log_time.py:30 |     0.0012s separating Current[A] into segments using incremental linear fit
# INFO | D:\Coding\PyDPEET_BA\pythonProject\pydpeet\src\pydpeet\process\sequence\utils\console_prints\log_time.py:30 |     0.0013s separating Power[W] into segments using incremental linear fit
# INFO | D:\Coding\PyDPEET_BA\pythonProject\pydpeet\src\pydpeet\process\sequence\utils\console_prints\log_time.py:30 |     0.0401s adding Length_Segment_Voltage[V] to calculate the dominating segments
# INFO | D:\Coding\PyDPEET_BA\pythonProject\pydpeet\src\pydpeet\process\sequence\utils\console_prints\log_time.py:30 |     0.0019s adding Length_Segment_Current[A] to calculate the dominating segments
# INFO | D:\Coding\PyDPEET_BA\pythonProject\pydpeet\src\pydpeet\process\sequence\utils\console_prints\log_time.py:30 |     0.0018s adding Length_Segment_Power[W] to calculate the dominating segments
# INFO | D:\Coding\PyDPEET_BA\pythonProject\pydpeet\src\pydpeet\process\sequence\utils\console_prints\log_time.py:30 |     0.0044s suppressing smaller segments
# INFO | D:\Coding\PyDPEET_BA\pythonProject\pydpeet\src\pydpeet\process\sequence\utils\console_prints\log_time.py:30 |     0.0365s attempting to merge neighboring segments
# WARNING | D:\Coding\PyDPEET_BA\pythonProject\pydpeet\src\pydpeet\process\sequence\utils\processing\widen_constant_segments.py:167 | Removed segments during finetuning of the width in 'Segment_Current[A]': 11:9111, 43678:44495 ...
# WARNING | D:\Coding\PyDPEET_BA\pythonProject\pydpeet\src\pydpeet\process\sequence\utils\processing\widen_constant_segments.py:173 | Removed segments during finetuning of the width in 'Segment_Power[W]': 5:10
# INFO | D:\Coding\PyDPEET_BA\pythonProject\pydpeet\src\pydpeet\process\sequence\utils\console_prints\log_time.py:30 |     0.0733s fine tuning width of constant segments to better fit the data
# INFO | D:\Coding\PyDPEET_BA\pythonProject\pydpeet\src\pydpeet\process\sequence\step_analyzer.py:204 | starting annotation...
# INFO | D:\Coding\PyDPEET_BA\pythonProject\pydpeet\src\pydpeet\process\sequence\utils\console_prints\log_time.py:30 |     0.0180s adding ID annotation
# INFO | D:\Coding\PyDPEET_BA\pythonProject\pydpeet\src\pydpeet\process\sequence\utils\console_prints\log_time.py:30 |     0.0076s adding variable annotation
# INFO | D:\Coding\PyDPEET_BA\pythonProject\pydpeet\src\pydpeet\process\sequence\utils\console_prints\log_time.py:30 |     0.1880s adding duration, length, min, max, avg, type, direction, slope annotation
# INFO | D:\Coding\PyDPEET_BA\pythonProject\pydpeet\src\pydpeet\process\sequence\utils\console_prints\log_time.py:30 |     0.0108s dropping temporary length and segment columns
# WARNING | D:\Coding\PyDPEET_BA\pythonProject\pydpeet\src\pydpeet\process\sequence\step_analyzer.py:222 | Skipping additional data checks and corrections...

# %%
df_segments = eet.extract_sequence_overview(df_primitives, config=eet.SequenceOverviewConfig.STEP_ANALYZER)
# Out:
# WARNING | D:\Coding\PyDPEET_BA\pythonProject\pydpeet\src\pydpeet\utils\guardrails.py:16 | Column 'Variable' has wrong data type.Expected: <class 'str'> but got object.Column 'Variable' has rows that are None and is therefore treated as a object.
# WARNING | D:\Coding\PyDPEET_BA\pythonProject\pydpeet\src\pydpeet\utils\guardrails.py:16 | Column 'Type' has wrong data type.Expected: <class 'str'> but got object.Column 'Type' has rows that are None and is therefore treated as a object.
# WARNING | D:\Coding\PyDPEET_BA\pythonProject\pydpeet\src\pydpeet\utils\guardrails.py:16 | Column 'Direction' has wrong data type.Expected: <class 'str'> but got object.Column 'Direction' has rows that are None and is therefore treated as a object.
# INFO | D:\Coding\PyDPEET_BA\pythonProject\pydpeet\src\pydpeet\process\sequence\step_analyzer.py:335 | analyzing segments...
# INFO | D:\Coding\PyDPEET_BA\pythonProject\pydpeet\src\pydpeet\process\sequence\utils\console_prints\log_time.py:30 |     0.0083s filtering by ID
# INFO | D:\Coding\PyDPEET_BA\pythonProject\pydpeet\src\pydpeet\process\sequence\utils\console_prints\log_time.py:30 |     0.0059s tag simple segments
# INFO | D:\Coding\PyDPEET_BA\pythonProject\pydpeet\src\pydpeet\process\sequence\utils\console_prints\log_time.py:30 |     0.0100s tag sequences
# INFO | D:\Coding\PyDPEET_BA\pythonProject\pydpeet\src\pydpeet\process\sequence\utils\console_prints\log_time.py:30 |     0.0709s assign longest sequence
# INFO | D:\Coding\PyDPEET_BA\pythonProject\pydpeet\src\pydpeet\process\sequence\utils\console_prints\log_time.py:30 |     0.0005s separate sequences and df_with_segments

# %%
eet.BatteryConfig.DEFAULT
# Out:
# _BatteryConfigClass(cell_name='Default', c_ref=4.8, soc_start=0, max_voltage=4.2, min_voltage=2.5, threshold_current=0.075, voltage_intervall=0.01, minimal_current_for_capacity=-1.2, maximal_current_for_capacity=-0.8, min_current_diff=1, max_time_diff=0.5, min_voltage_diff=0, ignore_negative_resistance_values=False)

# %% [markdown]
# ## Step 1: Filter blocks

# %%
charge_blocks, _ = eet.filter_and_split_df_by_blocks(
    df_segments_and_sequences=df_segments, df_primitives=df_primitives, rules=["CC_Charge"]
)

discharge_blocks, _ = eet.filter_and_split_df_by_blocks(
    df_segments_and_sequences=df_segments, df_primitives=df_primitives, rules=["CC_Discharge"]
)
# Out:
# WARNING | D:\Coding\PyDPEET_BA\pythonProject\pydpeet\src\pydpeet\utils\guardrails.py:16 | Column 'Variable' has wrong data type.Expected: <class 'str'> but got object.Column 'Variable' has rows that are None and is therefore treated as a object.
# WARNING | D:\Coding\PyDPEET_BA\pythonProject\pydpeet\src\pydpeet\process\sequence\utils\postprocessing\filter_df.py:248 | Using default standard columns:
# WARNING | D:\Coding\PyDPEET_BA\pythonProject\pydpeet\src\pydpeet\process\sequence\utils\postprocessing\filter_df.py:249 | ['Test_Time[s]', 'Voltage[V]', 'Current[A]', 'Power[W]']
# WARNING | D:\Coding\PyDPEET_BA\pythonProject\pydpeet\src\pydpeet\utils\guardrails.py:16 | Column 'Variable' has wrong data type.Expected: <class 'str'> but got object.Column 'Variable' has rows that are None and is therefore treated as a object.
# WARNING | D:\Coding\PyDPEET_BA\pythonProject\pydpeet\src\pydpeet\process\sequence\utils\postprocessing\filter_df.py:248 | Using default standard columns:
# WARNING | D:\Coding\PyDPEET_BA\pythonProject\pydpeet\src\pydpeet\process\sequence\utils\postprocessing\filter_df.py:249 | ['Test_Time[s]', 'Voltage[V]', 'Current[A]', 'Power[W]']

# %% [markdown]
# ## Step 2: add_efficiency_coulomb

# %%
eet.add_efficiency_coulomb(
    df=standardized_data,
    df_blocks_charge=charge_blocks,
    df_blocks_discharge=discharge_blocks,
    config=eet.BatteryConfig.DEFAULT,
    verbose=True,
).plot(x="Test_Time[s]", y="CoulombEfficiency", style="cx")
# Out:
# INFO | D:\Coding\PyDPEET_BA\pythonProject\pydpeet\src\pydpeet\process\analyze\efficiency.py:51 | Starting Coulomb Efficiency computation on dataframe of size 167889...
# INFO | D:\Coding\PyDPEET_BA\pythonProject\pydpeet\src\pydpeet\process\analyze\average.py:234 | ChargeThroughput column missing, computing via add_charge_throughput...
# INFO | D:\Coding\PyDPEET_BA\pythonProject\pydpeet\src\pydpeet\process\analyze\utils.py:28 |     0.0007s Processed charge throughput for whole DataFrame
# INFO | D:\Coding\PyDPEET_BA\pythonProject\pydpeet\src\pydpeet\process\analyze\average.py:241 | Total discharge computed: 4.7519 Ah
# INFO | D:\Coding\PyDPEET_BA\pythonProject\pydpeet\src\pydpeet\process\analyze\utils.py:28 |     0.0050s calculated total_discharge for one block
# INFO | D:\Coding\PyDPEET_BA\pythonProject\pydpeet\src\pydpeet\process\analyze\utils.py:28 |     0.0186s summarized all charge/discharge blocks
# INFO | D:\Coding\PyDPEET_BA\pythonProject\pydpeet\src\pydpeet\process\analyze\efficiency.py:124 | No valid charge/discharge blocks found. Skipping Coulomb Efficiency computation.
# <Axes: xlabel='Test_Time[s]'>
